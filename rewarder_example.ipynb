# %%
from rewarder import Rewarder
import json
import pandas as pd
from tqdm import tqdm

# %%
## example df
df = pd.read_csv('./data/ap/expanded_and_labeled_queries_with_pubmed_ap_n100_200candidates.csv')
df = df.sample(10)

# %%
def calculate_reward(rewarder: Rewarder, base_query_column='Q_name', expanded_query_colum='new_q'):
    def eval(row):
        base_query = row[base_query_column]        
        new_query = row[expanded_query_colum]
        return rewarder.reward_one(new_query, base_query)
    return eval

# %%
metric = 'recall'
at_n = 100
rewarder = Rewarder(
        "./data/cord_qrels.json", n_results=at_n, metric=metric
    )

tqdm.pandas()
df['new_query_recall'] = df.progress_apply(calculate_reward(rewarder), axis=1)
df
# Out:
# 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
#        index                                       Q_name  candidate  \
# 14664     39                    coronavirus heart impacts    current
# 6892      18                  coronavirus public datasets    disease
# 2718       6                  COVID inflammatory response   receptor
# 14162     37                     coronavirus outside body  territory
# 1723       3      coronavirus response to weather changes  infection
# 910        2         coronavirus social distancing impact     damage
# 16933     46               coronavirus hydroxychloroquine      study
# 1219       3      coronavirus response to weather changes    virtual
# 11142     29            serological tests for coronavirus   research
# 13506     36  impact of masks on coronavirus transmission   focusing
#
#                                                    new_q  base_reward  \
# 14664                  coronavirus heart impacts current     0.000355
# 6892                 coronavirus public datasets disease     0.000000
# 2718                COVID inflammatory response receptor     0.000000
# 14162                 coronavirus outside body territory     0.001175
# 1723   coronavirus response to weather changes infection     0.001608
# 910          coronavirus social distancing impact damage     0.000000
# 16933               coronavirus hydroxychloroquine study     0.000000
# 1219     coronavirus response to weather changes virtual     0.001608
# 11142         serological tests for coronavirus research     0.000000
# 13506  impact of masks on coronavirus transmission fo...     0.000000
#
#        new_reward  label  new_query_recall
# 14664    0.000000      0          0.000000
# 6892     0.000000      0          0.000000
# 2718     0.000000      0          0.000000
# 14162    0.000000      0          0.000000
# 1723     0.002048      1          0.014286
# 910      0.000000      0          0.000000
# 16933    0.000000      0          0.000000
# 1219     0.000000      0          0.000000
# 11142    0.000000      0          0.000000
# 13506    0.000000      0          0.000000
